# %%
# source code inspireed by
# https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html#model-training-and-validation-code

from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy

# show plot first run
# %matplotlib inline 
# test autocompletion with tab or tab+shift
# %config IPCompleter.greedy=True

# %%
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)

use_cuda = torch.cuda.is_available()
print('cuda_available:',use_cuda)

root = './data'

transform = transforms.Compose([
    # you can add other transformations in this list
    transforms.ToTensor()
])

print('Loading dataset')
train_set = datasets.FashionMNIST(root=root, train=True, transform=transform, download=True)
test_set = datasets.FashionMNIST(root=root, train=False, transform=transform, download=True)
print('Datasets loaded')

# hyperparameter
# TODO Find good hyperparameters
batch_size = 4
num_epochs = 20
learning_rate = 0.001
momentum = 0.9

# Load train and test data as dictionary!!!
data_loaders = {}
data_loaders['train'] = torch.utils.data.DataLoader(
                 dataset=train_set,
                 batch_size=batch_size,
                 shuffle=True)
data_loaders['test'] = torch.utils.data.DataLoader(
                dataset=test_set,
                batch_size=batch_size,
                shuffle=False)


# implement your own NNs
num_of_class = 10
class MyNeuralNetwork(nn.Module):
    def __init__(self):
        super(MyNeuralNetwork, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.fc = nn.Linear(7 * 7 * 32, num_of_class)
        self.drop = nn.Dropout(0.25)
        
    def forward(self, x):   
        out = self.layer1(x)
        out = self.drop(out)
        out = self.layer2(out)
        out = self.drop(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        return out
    
    def name(self):
        return "MyNeuralNetwork"

## training
model = MyNeuralNetwork()
print(model)
# Out:
# PyTorch Version:  1.3.1
# Torchvision Version:  0.4.2
# cuda_available: False
# Loading dataset
# Datasets loaded
# MyNeuralNetwork(
#   (layer1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Linear(in_features=1568, out_features=10, bias=True)
#   (drop): Dropout(p=0.25, inplace=False)
# )

# %%
# read nn model
#PATH = './bak-'+ model.name() +'.pth'
#model.load_state_dict(torch.load(PATH))

# %%
#optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
#optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
criterion = nn.CrossEntropyLoss()

train_acc_history = []
test_acc_history = []

train_loss_history = []
test_loss_history = []


best_acc = 0.0
since = time.time()
for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch, num_epochs - 1))
    print('-' * 10)

    # Each epoch has a training and validation phase
    for phase in ['train', 'test']:
        if phase == 'train':
            model.train()  # Set model to training mode
        else:
            model.eval()  # Set model to evaluate mode

        running_loss = 0.0
        running_corrects = 0

        for batch_idx, (inputs, labels) in enumerate(data_loaders[phase]):
            # zero the parameter gradients
            optimizer.zero_grad()
            
            #print(labels.shape)

            # forward
            # track history if only in train
            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                #print('in',inputs.shape)
                #print('out',outputs.shape)
                #print('labels',labels.shape)
                outputs.reshape(-1)
                loss = criterion(outputs, labels)

                _, preds = torch.max(outputs, 1)

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

            if batch_idx % 500 == 0:
                print('{} Batch: {} of {}'.format(phase, batch_idx, len(data_loaders[phase])))
                
            if batch_idx == 2000:
                break
                

        epoch_loss = running_loss / len(data_loaders[phase].dataset)
        epoch_acc = running_corrects.double() / len(data_loaders[phase].dataset)

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

        # deep copy the model
        if phase == 'test' and epoch_acc > best_acc:
            best_acc = epoch_acc
            best_model_wts = copy.deepcopy(model.state_dict())
        if phase == 'test':
            test_acc_history.append(epoch_acc)
            test_loss_history.append(epoch_loss)
        if phase == 'train':
            train_acc_history.append(epoch_acc)
            train_loss_history.append(epoch_loss)

    #print()
# Out:
# Epoch 0/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0893 Acc: 0.1020
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.3608 Acc: 0.6764
# Epoch 1/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0652 Acc: 0.1108
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.3104 Acc: 0.6931
# Epoch 2/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0583 Acc: 0.1123
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.3059 Acc: 0.6897
# Epoch 3/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0545 Acc: 0.1138
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2928 Acc: 0.6972
# Epoch 4/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0507 Acc: 0.1148
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.3085 Acc: 0.6903
# Epoch 5/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0498 Acc: 0.1155
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2846 Acc: 0.6962
# Epoch 6/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0483 Acc: 0.1165
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2699 Acc: 0.7023
# Epoch 7/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0483 Acc: 0.1162
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2729 Acc: 0.7066
# Epoch 8/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0455 Acc: 0.1170
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2703 Acc: 0.7029
# Epoch 9/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0494 Acc: 0.1158
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2660 Acc: 0.7088
# Epoch 10/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0452 Acc: 0.1171
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2696 Acc: 0.7067
# Epoch 11/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0458 Acc: 0.1171
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2519 Acc: 0.7093
# Epoch 12/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0438 Acc: 0.1178
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2486 Acc: 0.7126
# Epoch 13/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0419 Acc: 0.1178
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2489 Acc: 0.7107
# Epoch 14/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0433 Acc: 0.1179
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2506 Acc: 0.7081
# Epoch 15/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0439 Acc: 0.1178
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2535 Acc: 0.7141
# Epoch 16/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0414 Acc: 0.1182
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2499 Acc: 0.7092
# Epoch 17/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0429 Acc: 0.1182
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2587 Acc: 0.7063
# Epoch 18/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0405 Acc: 0.1185
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2331 Acc: 0.7176
# Epoch 19/19
# ----------
# train Batch: 0 of 15000
# train Batch: 500 of 15000
# train Batch: 1000 of 15000
# train Batch: 1500 of 15000
# train Batch: 2000 of 15000
# train Loss: 0.0411 Acc: 0.1183
# test Batch: 0 of 2500
# test Batch: 500 of 2500
# test Batch: 1000 of 2500
# test Batch: 1500 of 2500
# test Batch: 2000 of 2500
# test Loss: 0.2329 Acc: 0.7197

# %%
# save model
#print('Saving model',PATH)
#torch.save(model.state_dict(), PATH)

# %%
time_elapsed = time.time() - since
print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
print('Best val Acc: {:4f}'.format(best_acc))

acc_train_hist = []
acc_test_hist = []

acc_train_hist = [h.cpu().numpy() for h in train_acc_history]
acc_test_hist = [h.cpu().numpy() for h in test_acc_history]

plt.title("Validation/Test Accuracy vs. Number of Training Epochs")
plt.xlabel("Training Epochs")
plt.ylabel("Validation/Test Accuracy")
plt.plot(range(1,num_epochs+1),acc_train_hist,label="Train")
plt.plot(range(1,num_epochs+1),acc_test_hist,label="Test")
plt.ylim((0,1.))
plt.xticks(np.arange(1, num_epochs+1, 1.0))
plt.legend()
plt.savefig('ex3_3_acc_lenet.png')
plt.show()

#print(np.arange(1,num_epochs+1),train_loss_history)
#print(np.arange(1,num_epochs+1),test_loss_history)

plt.title("Validation/Test Loss vs. Number of Training Epochs")
plt.xlabel("Training Epochs")
plt.ylabel("Validation/Test Loss")
plt.plot(range(1,num_epochs+1),train_loss_history,label="Train")
plt.plot(range(1,num_epochs+1),test_loss_history,label="Test")
plt.ylim((0,2.3))
plt.xticks(np.arange(1, num_epochs+1, 1.0))
plt.legend()
plt.savefig('ex3_3_loss_lenet.png')
plt.show()


examples = enumerate(data_loaders['test'])
batch_idx, (example_data, example_targets) = next(examples)
with torch.no_grad():
    output = model(example_data)

categories = {
    0:	'T-shirt/top',
    1:	'Trouser',
    2:	'Pullover',
    3:	'Dress',
    4:	'Coat',
    5:	'Sandal',
    6:	'Shirt',
    7:	'Sneaker',
    8:	'Bag',
    9:	'Ankle boot'
}

for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Pred: {}".format(
      categories[output.data.max(1, keepdim=True)[1][i].item()]))
  plt.xticks([])
  plt.yticks([])
plt.show()
# Out:
# Training complete in 10m 48s
# Best val Acc: 0.719700
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-e59cbaa75aad> in <module>
#      56   plt.subplot(2,3,i+1)
#      57   plt.tight_layout()
# ---> 58   plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
#      59   plt.title("Pred: {}".format(
#      60       categories[output.data.max(1, keepdim=True)[1][i].item()]))
#
# IndexError: index 4 is out of bounds for dimension 0 with size 4
