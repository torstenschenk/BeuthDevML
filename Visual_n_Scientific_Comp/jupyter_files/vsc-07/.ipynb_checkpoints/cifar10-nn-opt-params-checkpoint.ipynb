# %%
import numpy as np
import matplotlib.pyplot as plt
import helper
import os
import random

# show plot first run
# %matplotlib inline 
# test autocompletion with tab or tab+shift
# %config IPCompleter.greedy=True 

random.seed(30)

class TwoLayerNeuralNetwork:
    """
    Ein 2-Layer 'fully-connected' neural network, d.h. alle Neuronen sind mit allen anderen
    verbunden. Die Anzahl der Eingabevektoren ist N mit einer Dimension D, einem 'Hidden'-Layer mit
    H Neuronen. Es soll eine Klassifikation über 10 Klassen (C) durchgeführt werden.
    Wir trainieren das Netzwerk mit einer 'Softmax'-Loss Funktion und einer L2 Regularisierung
    auf den Gewichtungsmatrizen (W1 und W2). Das Netzwerk nutzt ReLU Aktivierungsfunktionen nach
    dem ersten Layer.
    Die Architektur des Netzwerkes läßt sich abstrakt so darstellen:
    Eingabe - 'fully connected'-Layer - ReLU - 'fully connected'-Layer - Softmax

    Die Ausgabe aus dem 2.Layer sind die 'Scores' (Wahrscheinlichkeiten) für jede Klasse.
    """

    def __init__(self, input_size, hidden_size, output_size, std=1e-4):
        """
        Intitialisierung des Netzes - Die Gewichtungsmatrizen und die Bias-Vektoren werden mit
        Zufallswerten initialisiert.
        W1: 1.Layer Gewichte (D, H)
        b1: 1.Layer Bias (H,)
        W2: 2.Layer Gewichte (H, C)
        b2: 2.Layer Bias (C,)

        :param input_size: Die CIFAR-10 Bilder haben die Dimension D (32*32*3).
        :param hidden_size: Anzahl der Neuronen im Hidden-Layer H.
        :param output_size: Anzahl der Klassen C.
        :param std: Skalierungsfaktoren für die Initialisierung (muss klein sein)
        :return:
        """
        self.W1 = std * np.random.randn(input_size, hidden_size)
        self.b1 = std * np.random.randn(1, hidden_size)
        self.W2 = std * np.random.randn(hidden_size, output_size)
        self.b2 = std * np.random.randn(1, output_size)
        print('W1 shape:', self.W1.shape)
        print('b1 shape:', self.b1.shape)
        print('W2 shape:', self.W2.shape)
        print('b2 shape:', self.b2.shape)

    def softmax(self, z):
        z -= np.max(z)
        return np.exp(z) / np.sum(np.exp(z), axis=1, keepdims=True)

    def relu(self, x):
        return np.maximum(0.0, x)

    def relu_derivative(self, output):
        output[output <= 0] = 0
        output[output>0] = 1
        return output

    def loss_deriv_softmax(self, activation, y_batch):
        batch_size = y_batch.shape[0]
        dCda2 = activation
        dCda2[range(batch_size), y_batch] -= 1
        dCda2 /= batch_size
        return dCda2

    def loss_crossentropy(self, activation, y_batch):
        """
        Berechnet den loss (Fehler) des 2-Layer-Netzes

        :param batch_size: Anzahl der Eingabebilder in einem Batch über den der Fehler normalisiert werden muss
        :param y: Vektor mit den Trainingslabels y[i] enthält ein Label aus X[i] und jedes y[i] ist ein
                  Integer zwischen 0 <= y[i] < C (Anzahl der Klassen)
        :param reg: Regulasierungsstärke
        :return: loss - normalisierter Fehler des Batches
        """

        batch_size = y_batch.shape[0]
        correct_logprobs = -np.log(activation[range(batch_size), y_batch])
        loss = np.sum(correct_logprobs) / batch_size
        return loss


    def forward(self, X, y):
        """
        Führt den gesamten Forward Prozess durch und berechnet den Fehler (loss) und die Aktivierungen a1 und
        a2 und gibt diese Werte zuruück
        :param X: Trainings bzw. Testset
        :param y: Labels des Trainings- bzw. Testsets
        :return: loss, a1, a2
        """

        # Berechen Sie den score
        #N, D = X.shape
        # TODO: Berechnen Sie den Forward-Schritt und geben Sie den Vektor mit Scores zurueck
        # Nutzen Sie die ReLU Aktivierungsfunktion im ersten Layer
        # Berechnen Sie die Klassenwahrscheinlichkeiten unter Nutzung der softmax Funktion
        m1 = (X @ self.W1) + self.b1
        #print('forward m1.shape:',m1.shape)
        a1 = self.relu(m1)
        
        m2 = (a1 @ self.W2) + self.b2
        #print('forward m2.shape:',m2.shape)
        a2 = self.softmax(m2)
        
        # TODO: Berechnen Sie den Fehler mit der cross-entropy Funktion
        loss = self.loss_crossentropy(a2, y)

        return loss, a1, a2

    def backward(self, a1, a2, X, y):
        """
        Backward pass- dabei wird der Gradient der Gewichte W1, W2 und der Biases b1, b2 aus den Ausgaben des Netzes
        berechnet und die Gradienten der einzelnen Layer als ein Dictionary zurückgegeben.
        Zum Beispiel sollte grads['W1'] die Gradienten von self.W1 enthalten (das ist eine Matrix der gleichen Größe
        wie self.W1.
        :param a1: Aktivierung aus dem 1.Layer
        :param a2: Aktivierung aus dem 2.Layer -> Output des Netzes
        :param X:
        :param y:
        :return:
        """
        # Nutzen Sie dabei die Notizen aus der Vorlesung und die gegebenen Ableitungsfunktionen
        # please use the appropriate loss functions 
        # YOUR CODE HERE
        # Backward pass: Berechnen Sie die Gradienten
        N, D = X.shape
        
        # W1' = X.T * ( ( (2*(a2-yc)*relu(a2)) * W2.T ) * relu(a1) ) ## use relu(a2) or not??? no neg val can pass through
        # b1' = 1 * ( ( (2*(a2-yc)*relu(a2)) * W2.T ) * relu(a1) )
        # W2' = a1.T * 2*(a2 - yc)
        # v2' = 1 * 2*(a2 - yc)

        # dCostda2
        #print('backw a2 shape:',a2.shape)
        dCda2  = self.loss_deriv_softmax(a2,y)
        #print('backw dCda2 shape:',dCda2.shape)
        #dm2dW2 = a1 # only for W2
        #dm2da1 = W2 # only for W1
        da1dm1 = self.relu_derivative(a1) # only for W1
        #print('backw da1dm1 shape:',da1dm1.shape)
        #dm1db1 = 1 # ignore
        #dm1dw1 = X_batch # just use X_batch

        # dCdW2 = (W2') = dCda2 * da2dm2 * dm2dW2
        # calc in order: dCdW2 = dm2dW2 * (dCda2 * da2dm2)  
        # fit dimension: dCdW2 = dm2dW2.T * (dCda2 * da2dm2)

        # b2' = dm1db1 * dCda2 * da2dm2  # first term is 1*
        # b2' = dCda2 * da2dm2 # mean over axis=0

        # dCdW1 = (W1') = dCda2 * da2dm2 * dm2da1 * da1dm1 * dm1dw1
        # calc in order: dCdW1 = X_batch * [ ((dCda2 * da2dm2)*dm2da1) * da1dm1 ]
        # fit dimension: dCdW1 = X_batch.T * [ ((dCda2 * da2dm2)*dm2da1.T) * da1dm1 ]

        # replace: dCdW2 = a1.T * (dCda2 * da2dm2)
        #    dCdb2 = b2' = mean_over_axis0( dCda2 * da2dm2 )
        #          dCdW1 = X_batch.T * [ ((dCda2 * da2dm2)*W2.T) * relu_derivative(a1) ]
        #    dCdb1 = b1' = mean_over_axis0( ((dCda2 * da2dm2)*W2.T) * relu_derivative(a1) )
        
        # implementation
        #tmp1 = dCda2 
        #tmp1 = torch.mul(dCda2,da2dm2) # *relu_deriv element wise mult
        #print(dCda2.shape, self.W2.shape)
        tmp2 = dCda2 @ self.W2.T
        #print(tmp2.shape, da1dm1.shape)
        
        ### mult!!!
        tmp3 = tmp2 * da1dm1 # *relu_deriv element wise mult
        
        #dCdW2 = a1.T @ dCda2       print('dCdW2 shape:',dCdW2.shape)Cdb2 = np.mean( dCda2, axis=0 )
        dCdW1 = X.T @ tmp3
        dCdb1 = np.mean( tmp3, axis=0 )

        dCdW2 = a1.T @ dCda2
        dCdb2 = np.mean( dCda2, axis=0 )

        # function should return 4 derivatives with respect to
        # W1, W2, b1, b2        
        # Füllen Sie das Dictionary grads['W2'], grads['b2'], grads['W1'], grads['b1']
        grads = {}
        grads['W1'] = dCdW1
        grads['b1'] = dCdb1
        grads['W2'] = dCdW2
        grads['b2'] = dCdb2
        
        return grads
        
    def train(self, X, y, X_val, y_val,
              learning_rate=1e-3, learning_rate_decay=0.95, num_iters=100,
              batch_size=200, verbose=False):
        """
        Training des Neuronalen Netzwerkes unter der Nutzung des iterativen
        Optimierungsverfahrens Stochastic Gradient Descent
        Train this neural network using stochastic gradient descent.

        :param X: Numpy Array der Größe (N,D)
        :param y: Numpy Array der Größe (N,) mit den jeweiligen Labels y[i] = c. Das bedeutet, dass X[i] das label c hat
                  mit 0 <= c < C
        :param X_val: Numpy Array der Größe (N_val,D) mit den Validierungs-/Testdaten
        :param y_val: Numpy Array der Größe (N_val,) mit den Labels für die Validierungs-/Testdaten
        :param learning_rate: Faktor der Lernrate für den Optimierungsprozess
        :param learning_rate_decay: gibt an, inwieweit die Lernrate in jeder Epoche angepasst werden soll
        :param reg: Stärke der Regularisierung
        :param num_iters: Anzahl der Iterationen der Optimierung
        :param batch_size: Anzahl der Trainingseingabebilder, die in jedem forward-Schritt mitgegeben werden sollen
        :param verbose: boolean, ob etwas ausgegeben werden soll
        :return: dict (fuer die Auswertung) - enthält Fehler und Genauigkeit der Klassifizierung für jede Iteration bzw. Epoche
        """
        num_train = X.shape[0]
        iterations_per_epoch = int(max(num_train / batch_size, 1))

        # Wir nutzen einen Stochastischen Gradient Decent (SGD) Optimierer um unsere
        # Parameter W1,W2,b1,b2 zu optimieren
        loss_history = []
        loss_val_history = []
        train_acc_history = []
        val_acc_history = []

        sample_propabilities = np.ones(X.shape[0])
        for it in range(num_iters):
            X_batch = None
            y_batch = None

            ############################
            # TODO: Erzeugen Sie einen zufälligen Batch der Größe batch_size
            # aus den Trainingsdaten und speichern diese in X_batch und y_batch
            # X_batch
            # y_batch 
            idx = random.sample(range(0, num_train), batch_size)
            X_batch = X[idx]
            y_batch = y[idx]
            
            ############################

            # TODO: Berechnung von loss und gradient für den aktuellen Batch
            #print('X_batch shape:',X_batch.shape)
            #print('y_batch shape:',y_batch.shape)
            loss, a1, a2 = self.forward(X_batch, y_batch)
            # Merken des Fehlers für den Plot
            loss_history.append(loss)
            
            # Jetzt backward pass (Gradienten berechnen).
            # backward pass 
            grads = self.backward(a1, a2, X_batch, y_batch)
            
            # Berechnung des Fehlers mit den aktuellen Parametern (W, b)
            # mit dem Testset
            loss_val, a1_val, a2_val = self.forward(X_val, y_val)
            loss_val_history.append(loss_val)

            ############################
            # TODO: Nutzen Sie die Gradienten aus der Backward-Funktion und passen
            # Sie die Parameter an (self.W1, self.b1 etc). Diese werden mit der Lernrate
            # gewichtet

            self.W1 -= learning_rate * grads['W1']
            self.W2 -= learning_rate * grads['W2']
            self.b1 -= learning_rate * grads['b1']
            self.b2 -= learning_rate * grads['b2']
            
            ############################

            # Ausgabe des aktuellen Fehlers. Diese sollte am Anfang erstmal nach unten gehen
            # kann aber immer etwas schwanken.
            if verbose and it % 100 == 0:
                print('iteration %d / %d: loss %f' % (it, num_iters, loss))

            # Wir überprüfen jede Epoche die Genauigkeit (von Trainingsset und Testset)
            # und dämpfen die Lernrate
            if it % iterations_per_epoch == 0:
                # Überprüfung der Klassifikationsgenauigkeit
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_history.append(train_acc)
                val_acc_history.append(val_acc)
                print('epoch done... acc', val_acc)

                # Dämpfung der Lernrate
                learning_rate *= learning_rate_decay

        # Zum Plotten der Genauigkeiten geben wir die
        # gesammelten Daten zurück
        return {
            'loss_history': loss_history,
            'loss_val_history': loss_val_history,
            'train_acc_history': train_acc_history,
            'val_acc_history': val_acc_history,
        }

    def predict(self, X):
        """
        Benutzen Sie die trainierten Gewichte des 2-Layer-Netzes um die Klassen für das
        Validierungsset vorherzusagen. Dafür müssen Sie für das/die Eingabebilder X nur
        die Scores berechnen. Der höchste Score ist die vorhergesagte Klasse. Dieser wird in y_pred
        geschrieben und zurückgegeben.

        :param X: Numpy Array der Größe (N,D)
        :return: y_pred Numpy Array der Größe (N,) die die jeweiligen Labels für alle Elemente in X enthaelt.
        y_pred[i] = c bedeutet, das fuer X[i] die Klasse c mit 0<=c<C vorhergesagt wurde
        """
        #y_pred = None
        m1 = (X @ self.W1) + self.b1
        #print('forward m1.shape:',m1.shape)
        a1 = self.relu(m1)
        
        a2 = (a1 @ self.W2) + self.b2
        #print('forward m2.shape:',m2.shape)
        #a2 = self.softmax(m2)
        
        ############################
        # TODO: Implementieren Sie die Vorhersage. D.h. für ein/mehrere Bild/er mit den gelernten
        # Parametern den Wahrscheinlichkeit berechnen.
        # np.argmax in dem Wahrscheinlichkeitsvektor ist die wahrscheinlichste Klasse
        ############################
        # Implementieren Sie nochmals den Forward pass um die Wahrscheinlichkeiten
        # vorherzusagen
        y_pred = np.argmax(a2, axis=1)
        #print('y_pred:',y_pred)
        return y_pred


if __name__ == '__main__':
    X_train, y_train, X_val, y_val = helper.prepare_CIFAR10_images()
    # TODO: Laden der Bilder. Hinweis - wir nutzen nur die Trainigsbilder zum Trainieren und die
    # Validierungsbilder zum Testen.
    print('Train data shape: ', X_train.shape)
    print('Train labels shape: ', y_train.shape)
    print('Validation data shape: ', X_val.shape)
    print('Validation labels shape: ', y_val.shape)

    # Grösse der Bilder
    input_size = 32 * 32 * 3
    # Anzahl der Klassen
    num_classes = 10

    #############################################
    # Hyperparameter
    #############################################

    # TODO: mit diesen Parametern sollten Sie in etwa auf eine
    # Klassifikationsgenauigkeit von 43% kommen. Optimieren Sie die
    # Hyperparameter um die Genauigkeit zu erhöhen (bitte tun sie das
    # systematisch und nicht einfach durch probieren - also z.B. in einem
    # for-loop eine Reihe von Parametern testen und die Einzelbilder abspeichern)
    
    hidden_size = 50   # Anzahl der Neuronen im Hidden Layer
    num_iter = 3000  # Anzahl der Optimierungsiterationen
    batch_size = 100  # Eingabeanzahl der Bilder
    learning_rate = 0.001  # Lernrate
    learning_rate_decay = 0.95  # Lernratenabschwächung
    
    ##
    opt_mult = np.array([1,250,10,0.0001,0.005])
    store_best0 = hidden_size 
    store_best1 = num_iter
    store_best2 = batch_size
    store_best3 = learning_rate
    store_best4 = learning_rate_decay
    
    # score
    acc = 0.0
    acc_tmp = 0.0
    
    sign = 1
    step = 0 # 0,1,2
    opt_param = 0 # param edited at moment
    
    
    for i in range(100):
        if step == 2:
            opt_param += 1
            opt_param %=5
            step = 0
        
        if step == 0:
            sign = 1
        if step == 1:
            sign = -1
            
        # set new params
        if opt_param == 0:
            # update hidden_size
            #opt_param = hidden_size
            hidden_size += int(opt_mult[opt_param]*sign)
        elif opt_param == 1:    
            # update num_iter
            #opt_param = num_iter
            num_iter += int(opt_mult[opt_param]*sign)
        elif opt_param == 2:
            # update batch_size
            #opt_param = batch_size
            batch_size += int(opt_mult[opt_param]*sign)
        elif opt_param == 3:
            # update learning_rate
            #opt_param = learning_rate
            learning_rate += (opt_mult[opt_param]*sign)
        elif opt_param == 4:
            # update learning_rate_decay
            #opt_param = learning_rate_decay
            learning_rate_decay += (opt_mult[opt_param]*sign)
        
        
        print('hiddensize:',hidden_size)
        
       # print(input_size, hidden_size,num_classes)
        net = TwoLayerNeuralNetwork(input_size, hidden_size, num_classes)

        # Train the network
        stats = net.train(X_train, y_train, X_val, y_val,
                            learning_rate=learning_rate, learning_rate_decay=learning_rate_decay, 
                          num_iters=num_iter, batch_size=batch_size, verbose=True)

        print('Final training loss: ', stats['loss_history'][-1])
        print('Final validation loss: ', stats['loss_val_history'][-1])

        print('Final validation accuracy: ', stats['val_acc_history'][-1])
        
        acc = stats['val_acc_history'][-1]

        helper.plot_net_weights(net)
        name = 'nr_'+str(i)+'_acc_hsz_'+str(hidden_size)+'_numi_'+str(num_iter)+'_bat_'+str(batch_size)+'_lrate_'+str(learning_rate)+'_ldec_'+str(learning_rate_decay)+'_acc_'+str(acc)+'.png'
        helper.plot_accuracy(stats,name)
        name = 'nr_'+str(i)+'_loss_hsz_'+str(hidden_size)+'_numi_'+str(num_iter)+'_bat_'+str(batch_size)+'_lrate_'+str(learning_rate)+'_ldec_'+str(learning_rate_decay)+'_acc_'+str(acc)+'.png'
        helper.plot_loss(stats,name)
        
        if acc > acc_tmp:
            acc_tmp = acc
            # keep value and continue
            if opt_param == 0:
                # update hidden_size
                store_best0 = hidden_size
            elif opt_param == 1:    
                # update num_iter
                #opt_param = num_iter
                store_best1 = num_iter
            elif opt_param == 2:
                # update batch_size
                #opt_param = batch_size
                 store_best2 = batch_size
            elif opt_param == 3:
                # update learning_rate
                #opt_param = learning_rate
                store_best3 = learning_rate
            elif opt_param == 4:
                # update learning_rate_decay
                #opt_param = learning_rate_decay
                store_best4 = learning_rate_decay
        else:
            step +=1
            if opt_param == 0:
                # reset value
                hidden_size = int(store_best0)
            elif opt_param == 1:
                num_iter = int(store_best1)
            elif opt_param == 2:
                batch_size = int(store_best2)
            elif opt_param == 3:
                learning_rate = store_best3
            elif opt_param == 4:
                learning_rate_decay = store_best4
        
        print('step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc')
        print(step, opt_param,hidden_size, num_iter, batch_size,  learning_rate, learning_rate_decay, acc)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# hiddensize: 51
# W1 shape: (3072, 51)
# b1 shape: (1, 51)
# W2 shape: (51, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302589
# epoch done... acc 0.145
# iteration 100 / 3000: loss 2.147321
# iteration 200 / 3000: loss 1.974246
# iteration 300 / 3000: loss 1.975044
# iteration 400 / 3000: loss 1.872554
# epoch done... acc 0.332
# iteration 500 / 3000: loss 1.923313
# iteration 600 / 3000: loss 1.775078
# iteration 700 / 3000: loss 1.896097
# iteration 800 / 3000: loss 1.771453
# iteration 900 / 3000: loss 1.849839
# epoch done... acc 0.372
# iteration 1000 / 3000: loss 1.827040
# iteration 1100 / 3000: loss 1.741011
# iteration 1200 / 3000: loss 1.542408
# iteration 1300 / 3000: loss 1.612386
# iteration 1400 / 3000: loss 1.816933
# epoch done... acc 0.39
# iteration 1500 / 3000: loss 1.601437
# iteration 1600 / 3000: loss 1.623135
# iteration 1700 / 3000: loss 1.720973
# iteration 1800 / 3000: loss 1.510330
# iteration 1900 / 3000: loss 1.639906
# epoch done... acc 0.411
# iteration 2000 / 3000: loss 1.669662
# iteration 2100 / 3000: loss 1.550308
# iteration 2200 / 3000: loss 1.732787
# iteration 2300 / 3000: loss 1.597927
# iteration 2400 / 3000: loss 1.756660
# epoch done... acc 0.424
# iteration 2500 / 3000: loss 1.723655
# iteration 2600 / 3000: loss 1.508438
# iteration 2700 / 3000: loss 1.674059
# iteration 2800 / 3000: loss 1.526682
# iteration 2900 / 3000: loss 1.549852
# epoch done... acc 0.436
# Final training loss:  1.676209824150801
# Final validation loss:  1.6110682019135374
# Final validation accuracy:  0.436
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 1 0 50 3000 100 0.001 0.95 0.436
# hiddensize: 49
# W1 shape: (3072, 49)
# b1 shape: (1, 49)
# W2 shape: (49, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302585
# epoch done... acc 0.115
# iteration 100 / 3000: loss 2.171351
# iteration 200 / 3000: loss 1.984446
# iteration 300 / 3000: loss 1.971018
# iteration 400 / 3000: loss 1.994909
# epoch done... acc 0.313
# iteration 500 / 3000: loss 1.904657
# iteration 600 / 3000: loss 1.799766
# iteration 700 / 3000: loss 1.839331
# iteration 800 / 3000: loss 1.770928
# iteration 900 / 3000: loss 1.657761
# epoch done... acc 0.374
# iteration 1000 / 3000: loss 1.803909
# iteration 1100 / 3000: loss 1.854296
# iteration 1200 / 3000: loss 1.728716
# iteration 1300 / 3000: loss 1.636216
# iteration 1400 / 3000: loss 1.647739
# epoch done... acc 0.39
# iteration 1500 / 3000: loss 1.697114
# iteration 1600 / 3000: loss 1.833744
# iteration 1700 / 3000: loss 1.696815
# iteration 1800 / 3000: loss 1.654235
# iteration 1900 / 3000: loss 1.654515
# epoch done... acc 0.398
# iteration 2000 / 3000: loss 1.597679
# iteration 2100 / 3000: loss 1.632523
# iteration 2200 / 3000: loss 1.522978
# iteration 2300 / 3000: loss 1.488755
# iteration 2400 / 3000: loss 1.699738
# epoch done... acc 0.429
# iteration 2500 / 3000: loss 1.483783
# iteration 2600 / 3000: loss 1.504307
# iteration 2700 / 3000: loss 1.516901
# iteration 2800 / 3000: loss 1.468358
# iteration 2900 / 3000: loss 1.814036
# epoch done... acc 0.428
# Final training loss:  1.5273024079407629
# Final validation loss:  1.6173288450975325
# Final validation accuracy:  0.428
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 2 0 50 3000 100 0.001 0.95 0.428
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 3250: loss 2.302559
# epoch done... acc 0.125
# iteration 100 / 3250: loss 2.132348
# iteration 200 / 3250: loss 2.018155
# iteration 300 / 3250: loss 2.041211
# iteration 400 / 3250: loss 1.936006
# epoch done... acc 0.325
# iteration 500 / 3250: loss 1.711881
# iteration 600 / 3250: loss 1.816923
# iteration 700 / 3250: loss 1.785894
# iteration 800 / 3250: loss 1.767612
# iteration 900 / 3250: loss 1.715454
# epoch done... acc 0.381
# iteration 1000 / 3250: loss 1.797758
# iteration 1100 / 3250: loss 1.764796
# iteration 1200 / 3250: loss 1.647738
# iteration 1300 / 3250: loss 1.742454
# iteration 1400 / 3250: loss 1.520381
# epoch done... acc 0.394
# iteration 1500 / 3250: loss 1.763095
# iteration 1600 / 3250: loss 1.685845
# iteration 1700 / 3250: loss 1.691494
# iteration 1800 / 3250: loss 1.859841
# iteration 1900 / 3250: loss 1.633656
# epoch done... acc 0.412
# iteration 2000 / 3250: loss 1.733858
# iteration 2100 / 3250: loss 1.683545
# iteration 2200 / 3250: loss 1.721528
# iteration 2300 / 3250: loss 1.483683
# iteration 2400 / 3250: loss 1.498671
# epoch done... acc 0.422
# iteration 2500 / 3250: loss 1.580414
# iteration 2600 / 3250: loss 1.644789
# iteration 2700 / 3250: loss 1.443393
# iteration 2800 / 3250: loss 1.764343
# iteration 2900 / 3250: loss 1.556464
# epoch done... acc 0.439
# iteration 3000 / 3250: loss 1.577430
# iteration 3100 / 3250: loss 1.526708
# iteration 3200 / 3250: loss 1.498855
# Final training loss:  1.6606999426949238
# Final validation loss:  1.5830167729705185
# Final validation accuracy:  0.439
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 1 1 50 3000 100 0.001 0.95 0.439
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 2750: loss 2.302618
# epoch done... acc 0.098
# iteration 100 / 2750: loss 2.124559
# iteration 200 / 2750: loss 1.964783
# iteration 300 / 2750: loss 1.970554
# iteration 400 / 2750: loss 1.903496
# epoch done... acc 0.314
# iteration 500 / 2750: loss 1.936455
# iteration 600 / 2750: loss 1.921178
# iteration 700 / 2750: loss 1.873226
# iteration 800 / 2750: loss 1.844775
# iteration 900 / 2750: loss 1.822256
# epoch done... acc 0.383
# iteration 1000 / 2750: loss 1.805205
# iteration 1100 / 2750: loss 1.813362
# iteration 1200 / 2750: loss 1.817810
# iteration 1300 / 2750: loss 1.626396
# iteration 1400 / 2750: loss 1.711290
# epoch done... acc 0.393
# iteration 1500 / 2750: loss 1.765295
# iteration 1600 / 2750: loss 1.861931
# iteration 1700 / 2750: loss 1.756976
# iteration 1800 / 2750: loss 1.458155
# iteration 1900 / 2750: loss 1.680686
# epoch done... acc 0.419
# iteration 2000 / 2750: loss 1.511564
# iteration 2100 / 2750: loss 1.586691
# iteration 2200 / 2750: loss 1.695821
# iteration 2300 / 2750: loss 1.554428
# iteration 2400 / 2750: loss 1.600450
# epoch done... acc 0.423
# iteration 2500 / 2750: loss 1.704197
# iteration 2600 / 2750: loss 1.674109
# iteration 2700 / 2750: loss 1.708830
# Final training loss:  1.5005981356574865
# Final validation loss:  1.6253756224132778
# Final validation accuracy:  0.423
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 2 1 50 3000 100 0.001 0.95 0.423
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302631
# epoch done... acc 0.119
# iteration 100 / 3000: loss 2.168622
# iteration 200 / 3000: loss 2.006041
# iteration 300 / 3000: loss 1.888366
# iteration 400 / 3000: loss 1.921721
# epoch done... acc 0.312
# iteration 500 / 3000: loss 1.938870
# iteration 600 / 3000: loss 1.807656
# iteration 700 / 3000: loss 1.939483
# iteration 800 / 3000: loss 1.838123
# epoch done... acc 0.374
# iteration 900 / 3000: loss 1.942581
# iteration 1000 / 3000: loss 1.820383
# iteration 1100 / 3000: loss 1.856656
# iteration 1200 / 3000: loss 1.777588
# iteration 1300 / 3000: loss 1.736075
# epoch done... acc 0.397
# iteration 1400 / 3000: loss 1.690516
# iteration 1500 / 3000: loss 1.663052
# iteration 1600 / 3000: loss 1.711001
# iteration 1700 / 3000: loss 1.561187
# epoch done... acc 0.403
# iteration 1800 / 3000: loss 1.659609
# iteration 1900 / 3000: loss 1.529035
# iteration 2000 / 3000: loss 1.681140
# iteration 2100 / 3000: loss 1.579246
# iteration 2200 / 3000: loss 1.804379
# epoch done... acc 0.42
# iteration 2300 / 3000: loss 1.726830
# iteration 2400 / 3000: loss 1.595087
# iteration 2500 / 3000: loss 1.807716
# iteration 2600 / 3000: loss 1.610600
# epoch done... acc 0.435
# iteration 2700 / 3000: loss 1.655673
# iteration 2800 / 3000: loss 1.705597
# iteration 2900 / 3000: loss 1.629020
# Final training loss:  1.554219240123609
# Final validation loss:  1.6107750534801224
# Final validation accuracy:  0.435
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 1 2 50 3000 100 0.001 0.95 0.435
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302577
# epoch done... acc 0.144
# iteration 100 / 3000: loss 2.088369
# iteration 200 / 3000: loss 2.047009
# iteration 300 / 3000: loss 1.974407
# iteration 400 / 3000: loss 1.843005
# iteration 500 / 3000: loss 1.866561
# epoch done... acc 0.338
# iteration 600 / 3000: loss 2.101132
# iteration 700 / 3000: loss 1.767580
# iteration 800 / 3000: loss 1.803235
# iteration 900 / 3000: loss 1.802385
# iteration 1000 / 3000: loss 1.897422
# epoch done... acc 0.372
# iteration 1100 / 3000: loss 1.831796
# iteration 1200 / 3000: loss 1.630783
# iteration 1300 / 3000: loss 1.744076
# iteration 1400 / 3000: loss 1.653039
# iteration 1500 / 3000: loss 1.724383
# iteration 1600 / 3000: loss 1.607898
# epoch done... acc 0.404
# iteration 1700 / 3000: loss 1.627096
# iteration 1800 / 3000: loss 1.734441
# iteration 1900 / 3000: loss 1.634495
# iteration 2000 / 3000: loss 1.631713
# iteration 2100 / 3000: loss 1.597742
# epoch done... acc 0.419
# iteration 2200 / 3000: loss 1.737816
# iteration 2300 / 3000: loss 1.564124
# iteration 2400 / 3000: loss 1.698862
# iteration 2500 / 3000: loss 1.486718
# iteration 2600 / 3000: loss 1.647420
# iteration 2700 / 3000: loss 1.754650
# epoch done... acc 0.423
# iteration 2800 / 3000: loss 1.583186
# iteration 2900 / 3000: loss 1.558839
# Final training loss:  1.646875752224983
# Final validation loss:  1.5976127350500897
# Final validation accuracy:  0.423
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 2 2 50 3000 100 0.001 0.95 0.423
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302581
# epoch done... acc 0.174
# iteration 100 / 3000: loss 2.094744
# iteration 200 / 3000: loss 2.092781
# iteration 300 / 3000: loss 1.951455
# iteration 400 / 3000: loss 1.984687
# epoch done... acc 0.33
# iteration 500 / 3000: loss 1.829766
# iteration 600 / 3000: loss 2.053447
# iteration 700 / 3000: loss 1.895806
# iteration 800 / 3000: loss 1.839556
# iteration 900 / 3000: loss 1.740461
# epoch done... acc 0.375
# iteration 1000 / 3000: loss 1.862143
# iteration 1100 / 3000: loss 1.793665
# iteration 1200 / 3000: loss 1.762770
# iteration 1300 / 3000: loss 1.883174
# iteration 1400 / 3000: loss 1.720675
# epoch done... acc 0.407
# iteration 1500 / 3000: loss 1.662044
# iteration 1600 / 3000: loss 1.720622
# iteration 1700 / 3000: loss 1.609032
# iteration 1800 / 3000: loss 1.767993
# iteration 1900 / 3000: loss 1.647927
# epoch done... acc 0.415
# iteration 2000 / 3000: loss 1.552962
# iteration 2100 / 3000: loss 1.550973
# iteration 2200 / 3000: loss 1.680470
# iteration 2300 / 3000: loss 1.590042
# iteration 2400 / 3000: loss 1.600504
# epoch done... acc 0.429
# iteration 2500 / 3000: loss 1.390099
# iteration 2600 / 3000: loss 1.697421
# iteration 2700 / 3000: loss 1.540703
# iteration 2800 / 3000: loss 1.567204
# iteration 2900 / 3000: loss 1.637440
# epoch done... acc 0.437
# Final training loss:  1.4522512762204545
# Final validation loss:  1.5879857743779657
# Final validation accuracy:  0.437
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 1 3 50 3000 100 0.001 0.95 0.437
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302587
# epoch done... acc 0.12
# iteration 100 / 3000: loss 2.166137
# iteration 200 / 3000: loss 2.027822
# iteration 300 / 3000: loss 1.874780
# iteration 400 / 3000: loss 1.856876
# epoch done... acc 0.315
# iteration 500 / 3000: loss 1.954937
# iteration 600 / 3000: loss 1.851283
# iteration 700 / 3000: loss 1.823153
# iteration 800 / 3000: loss 1.961794
# iteration 900 / 3000: loss 1.824631
# epoch done... acc 0.363
# iteration 1000 / 3000: loss 1.974692
# iteration 1100 / 3000: loss 1.675651
# iteration 1200 / 3000: loss 1.876520
# iteration 1300 / 3000: loss 1.678161
# iteration 1400 / 3000: loss 1.824931
# epoch done... acc 0.381
# iteration 1500 / 3000: loss 1.779385
# iteration 1600 / 3000: loss 1.571787
# iteration 1700 / 3000: loss 1.788056
# iteration 1800 / 3000: loss 1.750657
# iteration 1900 / 3000: loss 1.697729
# epoch done... acc 0.406
# iteration 2000 / 3000: loss 1.774907
# iteration 2100 / 3000: loss 1.745862
# iteration 2200 / 3000: loss 1.656642
# iteration 2300 / 3000: loss 1.691330
# iteration 2400 / 3000: loss 1.564556
# epoch done... acc 0.42
# iteration 2500 / 3000: loss 1.821681
# iteration 2600 / 3000: loss 1.623230
# iteration 2700 / 3000: loss 1.583863
# iteration 2800 / 3000: loss 1.616154
# iteration 2900 / 3000: loss 1.702298
# epoch done... acc 0.435
# Final training loss:  1.4498638575465466
# Final validation loss:  1.6258978692292079
# Final validation accuracy:  0.435
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 2 3 50 3000 100 0.001 0.95 0.435
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302570
# epoch done... acc 0.159
# iteration 100 / 3000: loss 2.099820
# iteration 200 / 3000: loss 2.008736
# iteration 300 / 3000: loss 1.985628
# iteration 400 / 3000: loss 1.776538
# epoch done... acc 0.321
# iteration 500 / 3000: loss 1.908511
# iteration 600 / 3000: loss 1.886138
# iteration 700 / 3000: loss 1.893239
# iteration 800 / 3000: loss 1.913556
# iteration 900 / 3000: loss 1.958947
# epoch done... acc 0.364
# iteration 1000 / 3000: loss 1.771621
# iteration 1100 / 3000: loss 1.790661
# iteration 1200 / 3000: loss 1.793710
# iteration 1300 / 3000: loss 1.731964
# iteration 1400 / 3000: loss 1.645562
# epoch done... acc 0.401
# iteration 1500 / 3000: loss 1.590435
# iteration 1600 / 3000: loss 1.628985
# iteration 1700 / 3000: loss 1.724849
# iteration 1800 / 3000: loss 1.656265
# iteration 1900 / 3000: loss 1.738426
# epoch done... acc 0.414
# iteration 2000 / 3000: loss 1.795583
# iteration 2100 / 3000: loss 1.573233
# iteration 2200 / 3000: loss 1.514837
# iteration 2300 / 3000: loss 1.555320
# iteration 2400 / 3000: loss 1.548933
# epoch done... acc 0.429
# iteration 2500 / 3000: loss 1.668025
# iteration 2600 / 3000: loss 1.423921
# iteration 2700 / 3000: loss 1.735005
# iteration 2800 / 3000: loss 1.506790
# iteration 2900 / 3000: loss 1.417055
# epoch done... acc 0.446
# Final training loss:  1.5279560937102605
# Final validation loss:  1.60406474293458
# Final validation accuracy:  0.446
# step opt_param: hidden_size num_iter batch_size learning_rate learning_rate_decay acc
# 1 4 50 3000 100 0.001 0.95 0.446
# hiddensize: 50
# W1 shape: (3072, 50)
# b1 shape: (1, 50)
# W2 shape: (50, 10)
# b2 shape: (1, 10)
# iteration 0 / 3000: loss 2.302628
# epoch done... acc 0.15
# iteration 100 / 3000: loss 2.207118
# iteration 200 / 3000: loss 2.080331
# iteration 300 / 3000: loss 2.023511
# iteration 400 / 3000: loss 2.024099
# epoch done... acc 0.308
# iteration 500 / 3000: loss 1.806797
# iteration 600 / 3000: loss 1.776699
# iteration 700 / 3000: loss 1.883769
# iteration 800 / 3000: loss 1.906469
# iteration 900 / 3000: loss 1.644280
# epoch done... acc 0.387
# iteration 1000 / 3000: loss 1.781005
# iteration 1100 / 3000: loss 1.764678
# iteration 1200 / 3000: loss 1.931586
# iteration 1300 / 3000: loss 1.647315
# iteration 1400 / 3000: loss 1.698902
# epoch done... acc 0.406
# iteration 1500 / 3000: loss 1.851757
# iteration 1600 / 3000: loss 1.610499
# iteration 1700 / 3000: loss 1.710183
# iteration 1800 / 3000: loss 1.625979
# iteration 1900 / 3000: loss 1.598117
# epoch done... acc 0.408
# iteration 2000 / 3000: loss 1.529403
# iteration 2100 / 3000: loss 1.539419
# iteration 2200 / 3000: loss 1.678052
# iteration 2300 / 3000: loss 1.529033
# iteration 2400 / 3000: loss 1.517530
# epoch done... acc 0.437
# iteration 2500 / 3000: loss 1.653567
# iteration 2600 / 3000: loss 1.753653
# iteration 2700 / 3000: loss 1.700696
# iteration 2800 / 3000: loss 1.750511
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8686433fccb3> in <module>
#     414         stats = net.train(X_train, y_train, X_val, y_val,
#     415                             learning_rate=learning_rate, learning_rate_decay=learning_rate_decay,
# --> 416                           num_iters=num_iter, batch_size=batch_size, verbose=True)
#     417
#     418         print('Final training loss: ', stats['loss_history'][-1])
#
# <ipython-input-27-8686433fccb3> in train(self, X, y, X_val, y_val, learning_rate, learning_rate_decay, num_iters, batch_size, verbose)
#     251             # Berechnung des Fehlers mit den aktuellen Parametern (W, b)
#     252             # mit dem Testset
# --> 253             loss_val, a1_val, a2_val = self.forward(X_val, y_val)
#     254             loss_val_history.append(loss_val)
#     255
#
# <ipython-input-27-8686433fccb3> in forward(self, X, y)
#     100         # Nutzen Sie die ReLU Aktivierungsfunktion im ersten Layer
#     101         # Berechnen Sie die Klassenwahrscheinlichkeiten unter Nutzung der softmax Funktion
# --> 102         m1 = (X @ self.W1) + self.b1
#     103         #print('forward m1.shape:',m1.shape)
#     104         a1 = self.relu(m1)
#
# KeyboardInterrupt:
